# %%
data = matrix(rbinom(15, 10, .35), nrow = 1000, ncol =15)
mean_vector = rowMeans(data)
hist(mean_vector)
# Out:
# Plot with title “Histogram of mean_vector”

# %%
data_small = matrix(rbinom(50, 10, .35), nrow = 1000, ncol =50)
mean_vector = rowMeans(data_small)
hist(mean_vector)
# Out:
# Plot with title “Histogram of mean_vector”

# %% [markdown]
# ### Check Central Limit Theorem
# We see more variance in data when we have less samples. We see that with more samples we observe data follows normal distribution.
